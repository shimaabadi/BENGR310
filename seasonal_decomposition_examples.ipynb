# %% [markdown]
# # Example 1:  airline passengers

# %% [markdown]
# the data represents the monthly total number of international airline passengers from 1949 to 1960.

# %%
from statsmodels.datasets import get_rdataset
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import STL

# Load the "airline" dataset
data = get_rdataset('AirPassengers').data['value']

plt.plot(data)

# %%
# Perform seasonal decomposition
from statsmodels.tsa.seasonal import seasonal_decompose
result = seasonal_decompose(data, model='additive', period=12)

# Plot the decomposition results
fig = result.plot()
fig.set_size_inches(8, 6)

# %%
# Perform STL decomposition
res = STL(data,period=12).fit()

# Plot the decomposition results
fig = res.plot()
fig.set_size_inches(8, 6)
